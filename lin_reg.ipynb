# %%
import pandas as pd
import csv

# %%
train = pd.read_csv("/content/salary-train.csv", engine = 'python', header = None)
train.head()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _next_iter_line(self, row_num)
#    2932         try:
# -> 2933             return next(self.data)
#    2934         except csv.Error as e:
#
# Error: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-639ce2f5644d> in <module>()
# ----> 1 train = pd.read_csv("/content/salary-train.csv", engine = 'python', header = None)
#       2 train.head()
#
# ...
